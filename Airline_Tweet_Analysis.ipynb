# %%
import pandas as pd
import numpy as np
from time import time

textdf = pd.read_csv('C:/DoPython/Venv39/Scripts/Project/preprocessed_tweets.csv', sep=',')
textdf.info()
textdf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14435 entries, 0 to 14434
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   airline_sentiment    14435 non-null  object
#  1   airline              14435 non-null  object
#  2   lemmatized_text_str  14435 non-null  object
# dtypes: object(3)
# memory usage: 338.4+ KB
#       airline_sentiment         airline  \
# 0          non-negative  Virgin America
# 1          non-negative  Virgin America
# 2          non-negative  Virgin America
# 3              negative  Virgin America
# 4              negative  Virgin America
# ...                 ...             ...
# 14430      non-negative        American
# 14431          negative        American
# 14432      non-negative        American
# 14433          negative        American
# 14434      non-negative        American
#
#                                      lemmatized_text_str
# 0                             virginamerica dhepburn say
# 1      virginamerica plus added commercial experience...
# 2      virginamerica today must mean need take anothe...
# 3      virginamerica really aggressive blast obnoxiou...
# 4                     virginamerica really big bad thing
# ...                                                  ...
# 14430     americanair thank get different flight chicago
# 14431  americanair leave 20 minute late flight warnin...
# 14432  americanair please bring american airline blac...
# 14433  americanair money change flight answer phone s...
# 14434  americanair 8 ppl need 2 know many seat next f...
#
# [14435 rows x 3 columns]

# %%
# Sentiment analysis using VADER
from nltk.sentiment.vader import SentimentIntensityAnalyzer
def predict_sentiment(review, printout, sentiment):
    analyzer = SentimentIntensityAnalyzer()
    scores = analyzer.polarity_scores(review)  # scores has 4 values: neg, neu, pos, compound
    pred = 'non-negative' if scores['compound'] > 0 else 'negative'
    if (printout==True):
        print(review)
        print('neg',scores['neg'],', neu',scores['neu'],', pos',scores['pos'],', normalized_sum',scores['compound'])
        print('Predicted:', pred, ', Actual:', sentiment, '\n')
    return pred
# show results for individual reviews
for i in range(0, len(textdf.index)):
    predict_sentiment(textdf.lemmatized_text_str[i], True, textdf.airline_sentiment[i])
# Out:
# virginamerica dhepburn say
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica plus added commercial experience tacky
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica today must mean need take another trip
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica really aggressive blast obnoxious entertainment guest face little recourse
# neg 0.345 , neu 0.468 , pos 0.187 , normalized_sum -0.3306
# Predicted: negative , Actual: negative
#
# virginamerica really big bad thing
# neg 0.486 , neu 0.514 , pos 0.0 , normalized_sum -0.5829
# Predicted: negative , Actual: negative
#
# virginamerica seriously would pay 30 flight seat play really bad thing fly va
# neg 0.377 , neu 0.492 , pos 0.131 , normalized_sum -0.5413
# Predicted: negative , Actual: negative
#
# virginamerica yes nearly every time fly vx ear worm go away
# neg 0.0 , neu 0.787 , pos 0.213 , normalized_sum 0.4019
# Predicted: non-negative , Actual: non-negative
#
# virginamerica really miss prime opportunity men without hat parody
# neg 0.158 , neu 0.585 , pos 0.256 , normalized_sum 0.2893
# Predicted: non-negative , Actual: non-negative
#
# virginamerica well notbut
# neg 0.0 , neu 0.488 , pos 0.512 , normalized_sum 0.2732
# Predicted: non-negative , Actual: non-negative
#
# virginamerica amaze arrive hour early good
# neg 0.0 , neu 0.385 , pos 0.615 , normalized_sum 0.7506
# Predicted: non-negative , Actual: non-negative
#
# virginamerica know suicide second lead death among teen 1024
# neg 0.545 , neu 0.455 , pos 0.0 , normalized_sum -0.8555
# Predicted: negative , Actual: non-negative
#
# virginamerica 3 pretty graphic much good minimal iconography
# neg 0.0 , neu 0.45 , pos 0.55 , normalized_sum 0.7269
# Predicted: non-negative , Actual: non-negative
#
# virginamerica great deal already think 2nd trip australia even go 1st trip yet p
# neg 0.0 , neu 0.745 , pos 0.255 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# virginamerica virginmedia fly fabulous seductive sky take stress away travel
# neg 0.197 , neu 0.563 , pos 0.239 , normalized_sum 0.1531
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thanks
# neg 0.0 , neu 0.256 , pos 0.744 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica sfopdx schedule still mia
# neg 0.355 , neu 0.645 , pos 0.0 , normalized_sum -0.296
# Predicted: negative , Actual: negative
#
# virginamerica excite first cross country flight lax mco heard nothing great thing virgin america 29daystogo
# neg 0.17 , neu 0.67 , pos 0.16 , normalized_sum -0.05
# Predicted: negative , Actual: non-negative
#
# virginamerica fly nyc sfo last week could fully sit seat due two large gentleman either side help
# neg 0.0 , neu 0.856 , pos 0.144 , normalized_sum 0.4019
# Predicted: non-negative , Actual: negative
#
# fly virginamerica
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica know would amazingly awesome bosfll please want fly
# neg 0.0 , neu 0.421 , pos 0.579 , normalized_sum 0.8051
# Predicted: non-negative , Actual: non-negative
#
# virginamerica first fare may three time carrier seat available select
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica love graphic
# neg 0.0 , neu 0.323 , pos 0.677 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica love hipster innovation feel good brand
# neg 0.0 , neu 0.292 , pos 0.708 , normalized_sum 0.8658
# Predicted: non-negative , Actual: non-negative
#
# virginamerica make boslas non stop permanently anytime soon
# neg 0.239 , neu 0.761 , pos 0.0 , normalized_sum -0.296
# Predicted: negative , Actual: non-negative
#
# virginamerica guy mess seat reserve seating friend guy give seat away want free internet
# neg 0.123 , neu 0.493 , pos 0.384 , normalized_sum 0.6486
# Predicted: non-negative , Actual: negative
#
# virginamerica status match program apply three week call email response
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica happen 2 ur vegan food option least say ur site know able 2 eat anything next 6 hr fail
# neg 0.179 , neu 0.821 , pos 0.0 , normalized_sum -0.5423
# Predicted: negative , Actual: negative
#
# virginamerica miss worry together soon
# neg 0.6 , neu 0.4 , pos 0.0 , normalized_sum -0.5423
# Predicted: negative , Actual: non-negative
#
# virginamerica amaze get cold air vent vx358 noair worstflightever roast sfotobos
# neg 0.0 , neu 0.741 , pos 0.259 , normalized_sum 0.5423
# Predicted: non-negative , Actual: negative
#
# virginamerica lax ewr middle seat red eye noob maneuver sendambien andchexmix
# neg 0.107 , neu 0.893 , pos 0.0 , normalized_sum -0.0516
# Predicted: negative , Actual: non-negative
#
# virginamerica hi bked cool birthday trip add elevate enter middle name flight booking problem
# neg 0.159 , neu 0.706 , pos 0.135 , normalized_sum -0.1027
# Predicted: negative , Actual: negative
#
# virginamerica hour operation club sfo post online current
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica help leave expensive headphone flight 89 iad lax today seat 2a one answering lf number lax
# neg 0.062 , neu 0.729 , pos 0.208 , normalized_sum 0.4215
# Predicted: non-negative , Actual: negative
#
# virginamerica await return phone call would prefer use online selfservice option
# neg 0.0 , neu 0.877 , pos 0.123 , normalized_sum 0.1027
# Predicted: non-negative , Actual: negative
#
# virginamerica great news america could start flight hawaii end year via pacificbiznews
# neg 0.0 , neu 0.728 , pos 0.272 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# nice rt virginamerica vibe moodlight takeoff touchdown moodlitmonday sciencebehindtheexperience
# neg 0.0 , neu 0.741 , pos 0.259 , normalized_sum 0.4215
# Predicted: non-negative , Actual: non-negative
#
# virginamerica moodlighting way fly best experience ever cool calm moodlitmonday
# neg 0.0 , neu 0.443 , pos 0.557 , normalized_sum 0.8316
# Predicted: non-negative , Actual: non-negative
#
# virginamerica freddieawards do do best airline around hand
# neg 0.0 , neu 0.448 , pos 0.552 , normalized_sum 0.8126
# Predicted: non-negative , Actual: non-negative
#
# virginamerica book flight hawaii
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica chat support work site
# neg 0.0 , neu 0.597 , pos 0.403 , normalized_sum 0.4019
# Predicted: non-negative , Actual: negative
#
# virginamerica view downtown los angeles hollywood sign beyond rain mountain
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica hey first time flyer next week excite hard time get flight add elevate account help
# neg 0.069 , neu 0.644 , pos 0.287 , normalized_sum 0.6597
# Predicted: non-negative , Actual: negative
#
# virginamerica plz help win bid upgrade flight 227 laxsea
# neg 0.0 , neu 0.435 , pos 0.565 , normalized_sum 0.7783
# Predicted: non-negative , Actual: non-negative
#
# virginamerica unused ticket move new city fly fly expires travelhelp
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica flight leave dallas seattle time feb 24
# neg 0.146 , neu 0.854 , pos 0.0 , normalized_sum -0.0516
# Predicted: negative , Actual: non-negative
#
# virginamerica elevategold good reason rock
# neg 0.0 , neu 0.58 , pos 0.42 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica dream
# neg 0.0 , neu 0.333 , pos 0.667 , normalized_sum 0.25
# Predicted: non-negative , Actual: non-negative
#
# virginamerica wow blow mind
# neg 0.0 , neu 0.441 , pos 0.559 , normalized_sum 0.5859
# Predicted: non-negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood last night tribute soundofmusic oscars2015 ladygaga think carrieunderwood agree
# neg 0.0 , neu 0.815 , pos 0.185 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood entertain
# neg 0.0 , neu 0.566 , pos 0.434 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica flight 769 way suppose take 30 minute ago website still show time flight thanks
# neg 0.0 , neu 0.828 , pos 0.172 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood julie andrews way though ladygaga impressive carrieunderwood
# neg 0.0 , neu 0.732 , pos 0.268 , normalized_sum 0.5106
# Predicted: non-negative , Actual: non-negative
#
# virginamerica wish fly atlanta soon
# neg 0.0 , neu 0.597 , pos 0.403 , normalized_sum 0.4019
# Predicted: non-negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood julie andrews hand
# neg 0.0 , neu 0.61 , pos 0.39 , normalized_sum 0.4939
# Predicted: non-negative , Actual: non-negative
# virginamerica flight leave dallas la february 24th
# neg 0.167 , neu 0.833 , pos 0.0 , normalized_sum -0.0516
# Predicted: negative , Actual: non-negative
#
# virginamerica hi excite 99 lgadal deal try 2 book since last week page never load thx
# neg 0.116 , neu 0.714 , pos 0.17 , normalized_sum 0.2477
# Predicted: non-negative , Actual: negative
#
# virginamerica know need spotify stat guiltypleasures
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood lady gaga amaze
# neg 0.0 , neu 0.588 , pos 0.412 , normalized_sum 0.5423
# Predicted: non-negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood carrie
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica new marketing song let u know think
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood julie andrew first lady gaga wowd last night carrie meh
# neg 0.098 , neu 0.902 , pos 0.0 , normalized_sum -0.0772
# Predicted: negative , Actual: non-negative
#
# virginamerica call 34 week ago add 3 flight 2014 elevatethey still show uphelp
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica ladygaga carrieunderwood great go carrieunderwood
# neg 0.0 , neu 0.549 , pos 0.451 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood sorry mary martin first
# neg 0.178 , neu 0.822 , pos 0.0 , normalized_sum -0.0772
# Predicted: negative , Actual: non-negative
#
# virginamerica ladygaga carrieunderwood love three really beat classic
# neg 0.0 , neu 0.625 , pos 0.375 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica flight 0736 dal dca 224 210pm tried check could status please
# neg 0.0 , neu 0.827 , pos 0.173 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica heyyyy guyyyys try get hour someone call please
# neg 0.0 , neu 0.777 , pos 0.223 , normalized_sum 0.3182
# Predicted: non-negative , Actual: negative
#
# virginamerica hi virgin hold 4050 minute earlier flight la nyc tonight earlier 1150pm
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica congrats win travelzoo award best deal airline u
# neg 0.0 , neu 0.212 , pos 0.788 , normalized_sum 0.9423
# Predicted: non-negative , Actual: non-negative
#
# virginamerica everything fine lose bag
# neg 0.36 , neu 0.4 , pos 0.24 , normalized_sum -0.2263
# Predicted: negative , Actual: negative
#
# virginamerica need change reservation virgin credit card need modify phone waive change fee online
# neg 0.0 , neu 0.833 , pos 0.167 , normalized_sum 0.3818
# Predicted: non-negative , Actual: non-negative
#
# virginamerica email customer service team let know need track number
# neg 0.0 , neu 0.874 , pos 0.126 , normalized_sum 0.0772
# Predicted: non-negative , Actual: non-negative
#
# virginamerica hi book flight need add baggage
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica airline awesome lax loft need step game 40 dirty table floor
# neg 0.171 , neu 0.588 , pos 0.241 , normalized_sum 0.296
# Predicted: non-negative , Actual: negative
#
# virginamerica worry great ride new plane great crew airline like
# neg 0.148 , neu 0.306 , pos 0.546 , normalized_sum 0.8316
# Predicted: non-negative , Actual: non-negative
#
# virginamerica awesome fly sat morning way correct bill
# neg 0.0 , neu 0.631 , pos 0.369 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# virginamerica watch best student film country 35000 foot cmfat35000feet
# neg 0.0 , neu 0.656 , pos 0.344 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica first time fly different ratepolicy medium bag thanks
# neg 0.0 , neu 0.734 , pos 0.266 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica go customer service anyway speak human soon possible thank
# neg 0.0 , neu 0.783 , pos 0.217 , normalized_sum 0.3612
# Predicted: non-negative , Actual: negative
#
# virginamerica happen doom
# neg 0.574 , neu 0.426 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: non-negative
#
# virginamerica supp biz traveler like southwestair customer service like jetblue neverflyvirginforbusiness
# neg 0.0 , neu 0.643 , pos 0.357 , normalized_sum 0.6124
# Predicted: non-negative , Actual: negative
#
# virginamerica apply member inflight crew teami 100 interested flightattendant dreampath g
# neg 0.0 , neu 0.769 , pos 0.231 , normalized_sum 0.4019
# Predicted: non-negative , Actual: non-negative
#
# virginamerica best whenever begrudgingly use airline delay late flight
# neg 0.17 , neu 0.519 , pos 0.311 , normalized_sum 0.4404
# Predicted: non-negative , Actual: negative
#
# virginamerica interest fly cancelled flight next four flight plannedneverflyvirginforbusiness
# neg 0.167 , neu 0.583 , pos 0.25 , normalized_sum 0.25
# Predicted: non-negative , Actual: negative
#
# virginamerica disappointing experience share every business traveler meet neverflyvirgin
# neg 0.258 , neu 0.565 , pos 0.177 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# virginamerica trouble add flight wife book elevate account help
# neg 0.218 , neu 0.565 , pos 0.218 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica bring reservation online use flight book problem code
# neg 0.252 , neu 0.748 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: non-negative
#
# virginamerica random q distribution elevate avatar bet kitty disproportionate share
# neg 0.0 , neu 0.784 , pos 0.216 , normalized_sum 0.296
# Predicted: non-negative , Actual: non-negative
#
# virginamerica 3 fly va life happen try change trip jperhi helpva home page let
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica site back
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica rnp yeah know
# neg 0.0 , neu 0.577 , pos 0.423 , normalized_sum 0.296
# Predicted: non-negative , Actual: non-negative
#
# virginamerica hi get point elevate account recent flight add flight point account
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica like tv interest video disappoint cancel flightled flight flight go jfk saturday
# neg 0.245 , neu 0.469 , pos 0.286 , normalized_sum 0.2023
# Predicted: non-negative , Actual: negative
#
# virginamerica land lax hour late flight bag check business travel friendly nomorevirgin
# neg 0.0 , neu 0.775 , pos 0.225 , normalized_sum 0.4939
# Predicted: non-negative , Actual: negative
#
# virginamerica flight 345 redirect
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica website btw new website great user experience time another redesign
# neg 0.0 , neu 0.709 , pos 0.291 , normalized_sum 0.6249
# Predicted: non-negative , Actual: negative
#
# virginamerica check add bag website work tried desktop mobile
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica let 2 scanned passenger leave plane tell someone remove bag 1st class bin uncomfortable
# neg 0.241 , neu 0.759 , pos 0.0 , normalized_sum -0.4215
# Predicted: negative , Actual: negative
#
# virginamerica phone number find call flight reservation
# neg 0.0 , neu 0.822 , pos 0.178 , normalized_sum 0.0772
# Predicted: non-negative , Actual: negative
#
# virginamerica anyone anything today website useless one answer phone
# neg 0.259 , neu 0.741 , pos 0.0 , normalized_sum -0.4215
# Predicted: negative , Actual: negative
#
# virginamerica try add boy prince ressie sf thursday virginamerica lax
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica must traveler miss flight late flight check bag miss morning appointment lose business sfo2lax
# neg 0.33 , neu 0.67 , pos 0.0 , normalized_sum -0.5994
# Predicted: negative , Actual: negative
#
# virginamerica check new music
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica direct flight fllsfo unexpected layover vegas 4 fuel yet peeps next bought vega flight sneaky
# neg 0.119 , neu 0.881 , pos 0.0 , normalized_sum -0.2263
# Predicted: negative , Actual: negative
# virginamerica late flight bag check lose business miss flight apt three people flight exp
# neg 0.264 , neu 0.736 , pos 0.0 , normalized_sum -0.5106
# Predicted: negative , Actual: negative
#
# virginamerica amaze customer service raeann sf best customerservice virginamerica fly
# neg 0.0 , neu 0.51 , pos 0.49 , normalized_sum 0.8271
# Predicted: non-negative , Actual: non-negative
#
# virginamerica call service line hang awesome sarcasm
# neg 0.173 , neu 0.455 , pos 0.373 , normalized_sum 0.4939
# Predicted: non-negative , Actual: negative
#
# virginamerica site trip try check get plain text version reluctant enter card info
# neg 0.143 , neu 0.857 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# virginamerica schedule sfo 2 dal flight 714 today change 24th due weather look like flight still
# neg 0.0 , neu 0.848 , pos 0.152 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# virginamerica getaway deal may 59 oneway lots cool city cheapflights farecompare
# neg 0.0 , neu 0.813 , pos 0.187 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica getaway deal may 59 oneway lots cool city cheapflights farecompare
# neg 0.0 , neu 0.813 , pos 0.187 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica getaway deal may 59 oneway lots cool city cheapflights farecompare
# neg 0.0 , neu 0.813 , pos 0.187 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica getaway deal may 59 oneway lots cool city cheapflights farecompare
# neg 0.0 , neu 0.813 , pos 0.187 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica great week
# neg 0.0 , neu 0.328 , pos 0.672 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# virginamerica come back phl already need take u horrible cold pleasecomeback
# neg 0.28 , neu 0.72 , pos 0.0 , normalized_sum -0.5423
# Predicted: negative , Actual: non-negative
#
# virginamerica concern fly plane need delay due tech stop
# neg 0.391 , neu 0.609 , pos 0.0 , normalized_sum -0.5423
# Predicted: negative , Actual: negative
#
# virginamerica best airline fly oneasy change reservationhelpful representative comfortable fly experience
# neg 0.0 , neu 0.545 , pos 0.455 , normalized_sum 0.8176
# Predicted: non-negative , Actual: non-negative
#
# virginamerica another rep kick butt naelah represent team beautifully thank
# neg 0.0 , neu 0.563 , pos 0.437 , normalized_sum 0.7351
# Predicted: non-negative , Actual: non-negative
#
# virginamerica beautiful frontend design right cool still book ticket bc backend secure
# neg 0.0 , neu 0.511 , pos 0.489 , normalized_sum 0.8225
# Predicted: non-negative , Actual: non-negative
#
# virginamerica love team run gate e9 la tonight wait delayed flight keep thing entertain
# neg 0.098 , neu 0.567 , pos 0.335 , normalized_sum 0.6808
# Predicted: non-negative , Actual: non-negative
#
# virginamerica use another browser 2015 brand reputation build tech response crossbrowser compatible website
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica flight flight book problem site totally folk problem
# neg 0.435 , neu 0.565 , pos 0.0 , normalized_sum -0.6597
# Predicted: negative , Actual: negative
#
# virginamerica like customer service 40 min delay connect passenger seem long va370
# neg 0.155 , neu 0.676 , pos 0.169 , normalized_sum 0.0516
# Predicted: non-negative , Actual: negative
#
# virginamerica thanks outstanding nycjfk crew move mountain get home san francisco tonight
# neg 0.0 , neu 0.592 , pos 0.408 , normalized_sum 0.7845
# Predicted: non-negative , Actual: non-negative
#
# virginamerica absolute best team customer service ever every time fly delight thank
# neg 0.0 , neu 0.459 , pos 0.541 , normalized_sum 0.891
# Predicted: non-negative , Actual: non-negative
#
# virginamerica provide complimentary upgrade first class available seat
# neg 0.0 , neu 0.707 , pos 0.293 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica need change flight schedule 9 hour 120 min wait time phone call intern help
# neg 0.0 , neu 0.828 , pos 0.172 , normalized_sum 0.4019
# Predicted: non-negative , Actual: negative
#
# virginamerica completely awesome experience last month boslas nonstop thanks awesome flight depart time vabeatsjblue
# neg 0.0 , neu 0.485 , pos 0.515 , normalized_sum 0.9133
# Predicted: non-negative , Actual: non-negative
#
# virginamerica watch oscars2015 jfksfo flight
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica flight 882 cancel flightled
# neg 0.333 , neu 0.667 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: non-negative
#
# virginamerica fail customer check process link tsa precheck
# neg 0.333 , neu 0.667 , pos 0.0 , normalized_sum -0.5423
# Predicted: negative , Actual: negative
#
# virginamerica fidifamilies u terrible airline give u hotel hotline number say sorry
# neg 0.346 , neu 0.551 , pos 0.102 , normalized_sum -0.4767
# Predicted: negative , Actual: negative
#
# virginamerica flight number 276 sfo cabo san lucas arrive yet
# neg 0.0 , neu 0.874 , pos 0.126 , normalized_sum 0.0772
# Predicted: non-negative , Actual: non-negative
#
# virginamerica chrysichrysic assistance yesterday cancel flightled flight give u hotel hotline shame
# neg 0.362 , neu 0.638 , pos 0.0 , normalized_sum -0.6249
# Predicted: negative , Actual: negative
#
# virginamerica another delay flight likingyoulessandless
# neg 0.365 , neu 0.635 , pos 0.0 , normalized_sum -0.3182
# Predicted: negative , Actual: negative
#
# virginamerica need register service dog first class ticket sfo dull phone queue hour longer pls advise
# neg 0.15 , neu 0.778 , pos 0.072 , normalized_sum -0.34
# Predicted: negative , Actual: negative
#
# virginamerica rock make watch oscar flight redcarpet oscar oscars2015
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica reallytallchris drop track
# neg 0.412 , neu 0.588 , pos 0.0 , normalized_sum -0.2732
# Predicted: negative , Actual: non-negative
#
# virginamerica always xoxo
# neg 0.0 , neu 0.333 , pos 0.667 , normalized_sum 0.6124
# Predicted: non-negative , Actual: non-negative
#
# virginamerica book seat flight buy even check creates much anxiety frustrate
# neg 0.318 , neu 0.541 , pos 0.142 , normalized_sum -0.3818
# Predicted: negative , Actual: negative
#
# virginamerica would think pay extra 100 buck rt luggage might afford hire extra hand sfo lame
# neg 0.206 , neu 0.637 , pos 0.157 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica best customer service rep world irmafromdallas take cake
# neg 0.0 , neu 0.656 , pos 0.344 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica find u flt lax sooner midnight monday would great customer service
# neg 0.0 , neu 0.709 , pos 0.291 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# virginamerica please provide status flight 769 imagine time web indicate dude weather andor dallas
# neg 0.0 , neu 0.85 , pos 0.15 , normalized_sum 0.3182
# Predicted: non-negative , Actual: negative
#
# virginamerica amazing staff super helpful run waltdisneyworld princesshalf spoil comfort
# neg 0.0 , neu 0.316 , pos 0.684 , normalized_sum 0.9186
# Predicted: non-negative , Actual: non-negative
#
# virginamerica pay premium fly across country cancel flight flight offer check fee upgrade love sad face
# neg 0.286 , neu 0.529 , pos 0.185 , normalized_sum -0.0772
# Predicted: negative , Actual: negative
#
# virginamerica question possible book seat infant 2 give option want seat
# neg 0.0 , neu 0.874 , pos 0.126 , normalized_sum 0.0772
# Predicted: non-negative , Actual: negative
#
# always together welcome rt virginamerica jessicajaymes welcome
# neg 0.0 , neu 0.455 , pos 0.545 , normalized_sum 0.7184
# Predicted: non-negative , Actual: non-negative
#
# virginamerica flight home dc sunset globe backtowinter back work refresh
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica understand need dm give answer damage luggage policy
# neg 0.286 , neu 0.714 , pos 0.0 , normalized_sum -0.4939
# Predicted: negative , Actual: negative
#
# virginamerica mean policy destroy luggage
# neg 0.467 , neu 0.533 , pos 0.0 , normalized_sum -0.5423
# Predicted: negative , Actual: negative
#
# virginamerica special assistance travel alone w2 kid 1 infant priority boarding
# neg 0.157 , neu 0.63 , pos 0.213 , normalized_sum 0.1779
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thank check ticket purchase customer happy
# neg 0.0 , neu 0.446 , pos 0.554 , normalized_sum 0.7351
# Predicted: non-negative , Actual: non-negative
#
# virginamerica website ever come back online
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica flight 713 love field sfo definitely cancel flightled monday february 23
# neg 0.112 , neu 0.503 , pos 0.385 , normalized_sum 0.7096
# Predicted: non-negative , Actual: non-negative
# virginamerica flight 0769 lga dfw time
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica driver license expired little month fly friday morning use expire license
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica problem flight book problem web site keep give error contact phone phone 30 minute wait
# neg 0.384 , neu 0.616 , pos 0.0 , normalized_sum -0.7964
# Predicted: negative , Actual: negative
#
# virginamerica reschedule cancel flightled flight online change button grey
# neg 0.196 , neu 0.686 , pos 0.118 , normalized_sum -0.2023
# Predicted: negative , Actual: negative
#
# virginamerica ring wait 35 minute book ticket vendor fix site
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica get flight tell 450 todaychecked email 450 tomorrow unacceptable
# neg 0.25 , neu 0.75 , pos 0.0 , normalized_sum -0.4588
# Predicted: negative , Actual: negative
#
# virginamerica flight lga cancel flighted stuck dallas call reschedule told could get flight today12
# neg 0.25 , neu 0.75 , pos 0.0 , normalized_sum -0.4588
# Predicted: negative , Actual: negative
#
# virginamerica pairing include red wine white offer redwineisbetter
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica website
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica site seem little wonked right may want look tried two browser css
# neg 0.0 , neu 0.902 , pos 0.098 , normalized_sum 0.0772
# Predicted: non-negative , Actual: negative
#
# virginamerica disappoint agent designate silver status check line dullesairport close assist pasengers
# neg 0.197 , neu 0.803 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: negative
#
# virginamerica plan include austin dallas route topnews arab emirate
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica normal receive reply central baggage baggageissues smh
# neg 0.247 , neu 0.753 , pos 0.0 , normalized_sum -0.3182
# Predicted: negative , Actual: negative
#
# virginamerica logan airport wait checkin 9am flight checkin desk open
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica jump dallasaustin market dallasnews
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica beat eps view take southwestair va love investor business daily
# neg 0.0 , neu 0.704 , pos 0.296 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica lister show monday 1230 130
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica begin dallasaustin flight april 889 ketr
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica congrats get business ewr sfolax fuck united fl1289 sfoewr clincher
# neg 0.198 , neu 0.452 , pos 0.35 , normalized_sum 0.4019
# Predicted: non-negative , Actual: negative
#
# virginamerica apply 2 week ago hear back fly week disappoint
# neg 0.252 , neu 0.748 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: negative
#
# virginamerica would love know policy damage luggage
# neg 0.258 , neu 0.403 , pos 0.339 , normalized_sum 0.25
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thank follow
# neg 0.0 , neu 0.444 , pos 0.556 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# virginamerica many apology r bad airline even respond cudtomers
# neg 0.327 , neu 0.561 , pos 0.112 , normalized_sum -0.5106
# Predicted: negative , Actual: negative
#
# virginamerica shame va make people spend money strand city airline land jfk reimburse
# neg 0.205 , neu 0.795 , pos 0.0 , normalized_sum -0.4767
# Predicted: negative , Actual: negative
#
# virginamerica ttinac11 dm
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica please flight sjc choice fly southwest vega
# neg 0.0 , neu 0.753 , pos 0.247 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica bad say take 10 14 day via confirmation email inquire 3 week claim 6 8 week
# neg 0.212 , neu 0.788 , pos 0.0 , normalized_sum -0.5423
# Predicted: negative , Actual: negative
#
# virginamerica flight bos la tomorrow cancel flightled notification wait time 1 hour rebook another airline
# neg 0.133 , neu 0.867 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# rt virginamerica meet match get status another airline upgrade restr
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica way fly elevate gold
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica guy flight cmh
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica lot apology thrown customer seevery sad thanks nothing bad airline ever
# neg 0.172 , neu 0.443 , pos 0.385 , normalized_sum 0.431
# Predicted: non-negative , Actual: negative
#
# virginamerica flight stuff wrong nothing bad flight ever
# neg 0.259 , neu 0.502 , pos 0.238 , normalized_sum -0.0644
# Predicted: negative , Actual: negative
#
# virginamerica issue find miss item plane help find airport plane head next
# neg 0.112 , neu 0.699 , pos 0.189 , normalized_sum 0.2732
# Predicted: non-negative , Actual: non-negative
#
# virginamerica match americanairlines status cool
# neg 0.0 , neu 0.635 , pos 0.365 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamericayou meet matchgot status another airline upgrade asarcoesar
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica try book flight guy website let lose business
# neg 0.252 , neu 0.748 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: negative
#
# virginamerica suck
# neg 0.744 , neu 0.256 , pos 0.0 , normalized_sum -0.4404
# Predicted: negative , Actual: negative
#
# virginamerica thanks
# neg 0.0 , neu 0.256 , pos 0.744 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica dmd issue persist
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica never recd cancelled flightlation notice leave w option fly ps drive la red eye mon w kid
# neg 0.071 , neu 0.826 , pos 0.103 , normalized_sum 0.1381
# Predicted: non-negative , Actual: negative
#
# virginamerica try book flight site
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica flight fly boston tomorrow need home cancel flightled flight anything
# neg 0.167 , neu 0.833 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# virginamerica stink flight cancel flighted psp jfk notification ability rebook disappoint expect well
# neg 0.374 , neu 0.404 , pos 0.222 , normalized_sum -0.4588
# Predicted: negative , Actual: negative
#
# virginamerica love guy song dance high school dance revue
# neg 0.0 , neu 0.656 , pos 0.344 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica website try check
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica do thank quick response apparently faster sit hold
# neg 0.0 , neu 0.762 , pos 0.238 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# virginamerica nervous flight dc lax get cancel flightled tomorrow send dm help
# neg 0.259 , neu 0.57 , pos 0.171 , normalized_sum -0.1027
# Predicted: negative , Actual: non-negative
#
# virginamerica cool picture another virginamerica plane wing site
# neg 0.0 , neu 0.753 , pos 0.247 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica keep great work
# neg 0.0 , neu 0.423 , pos 0.577 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# virginamerica goodness people love field amazing pressure texas beatstheothers crisis please fly ny
# neg 0.237 , neu 0.263 , pos 0.5 , normalized_sum 0.7906
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thanks great flight la boston pilot great job landing snow go back la seriously
# neg 0.071 , neu 0.462 , pos 0.466 , normalized_sum 0.886
# Predicted: non-negative , Actual: non-negative
#
# virginamerica please get new york area monday afternoon
# neg 0.0 , neu 0.753 , pos 0.247 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thanks much awesome support guy rock
# neg 0.0 , neu 0.292 , pos 0.708 , normalized_sum 0.8658
# Predicted: non-negative , Actual: non-negative
#
# virginamerica seat row 8 recline mention website soreback
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
# virginamerica flight 404 delay 2 hour la due mechanical problem handle like pro could toss u free drink
# neg 0.219 , neu 0.526 , pos 0.254 , normalized_sum 0.2023
# Predicted: non-negative , Actual: negative
#
# virginamerica cancel flight flight today precipitation scar
# neg 0.25 , neu 0.75 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# virginamerica twitter team guy kill reschedule soon possible thank
# neg 0.331 , neu 0.493 , pos 0.176 , normalized_sum -0.4939
# Predicted: negative , Actual: non-negative
#
# virginamerica guy charge 100 reschedule flight cancel flighted refuse refund deal
# neg 0.318 , neu 0.682 , pos 0.0 , normalized_sum -0.4939
# Predicted: negative , Actual: negative
#
# virginamerica access website safari iphone 6 seem work mac ipad need iphone add passbook
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica ipad iphone click checkin link email receive 24hrs flight
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica mobile site broken show headerelevateusernumofpointsavailable 0 number point let checkin
# neg 0.25 , neu 0.645 , pos 0.105 , normalized_sum -0.4215
# Predicted: negative , Actual: negative
#
# virginamerica really look forward flight let know reschedule diehardvirgin
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica cancel flight flight vx413 one sec delay airport next cancel flightledgoing email call reschedule
# neg 0.344 , neu 0.656 , pos 0.0 , normalized_sum -0.6486
# Predicted: negative , Actual: negative
#
# virginamerica problem link email checkin thanks
# neg 0.281 , neu 0.417 , pos 0.302 , normalized_sum 0.0516
# Predicted: non-negative , Actual: negative
#
# virginamerica change another airline get dc today unite able land dc cost 800 ugh
# neg 0.177 , neu 0.823 , pos 0.0 , normalized_sum -0.4215
# Predicted: negative , Actual: negative
#
# virginamerica look forward first flight today cancel flightled along subsequent one
# neg 0.167 , neu 0.833 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# virginamerica put great deal pdx las la pdx show love
# neg 0.0 , neu 0.491 , pos 0.509 , normalized_sum 0.8519
# Predicted: non-negative , Actual: non-negative
#
# virginamerica wish afford fly next friday go back home love everything airline
# neg 0.0 , neu 0.592 , pos 0.408 , normalized_sum 0.7845
# Predicted: non-negative , Actual: non-negative
#
# virginamerica go deal dallas dc deal dc dallas sad
# neg 0.279 , neu 0.721 , pos 0.0 , normalized_sum -0.4767
# Predicted: negative , Actual: negative
#
# virginamerica bug report guy
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica hold time call center bit much
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica like
# neg 0.0 , neu 0.286 , pos 0.714 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# virginamerica site help
# neg 0.0 , neu 0.426 , pos 0.574 , normalized_sum 0.4019
# Predicted: non-negative , Actual: negative
#
# virginamerica best flight attendant ever
# neg 0.0 , neu 0.488 , pos 0.512 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# awesome rt virginamerica watch nominate film 35000 foot meetthefleet oscar
# neg 0.0 , neu 0.687 , pos 0.313 , normalized_sum 0.6249
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thanks much
# neg 0.0 , neu 0.408 , pos 0.592 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica try reset password email never arrive help
# neg 0.244 , neu 0.756 , pos 0.0 , normalized_sum -0.3089
# Predicted: negative , Actual: negative
#
# virginamerica airline base silicon valley disruption fcmostinnovative incubator fastcompanys
# neg 0.238 , neu 0.762 , pos 0.0 , normalized_sum -0.3612
# Predicted: negative , Actual: non-negative
#
# virginamerica nicely do
# neg 0.0 , neu 0.408 , pos 0.592 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# virginamerica look forward watch oscar flight home tomorrow might even get something bubbly drink
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica reason delay departure vx 413 jfk afternoon
# neg 0.247 , neu 0.753 , pos 0.0 , normalized_sum -0.3182
# Predicted: negative , Actual: negative
#
# virginamerica today flight palm spring ca jfk ny cancel flightled
# neg 0.182 , neu 0.818 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# virginamerica hahaha virginamerica guy amaze love guy
# neg 0.0 , neu 0.261 , pos 0.739 , normalized_sum 0.9062
# Predicted: non-negative , Actual: non-negative
#
# virginamerica sound like fun
# neg 0.0 , neu 0.256 , pos 0.744 , normalized_sum 0.7003
# Predicted: non-negative , Actual: non-negative
#
# virginamerica update flight 413 jfk lax
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica spruce moose
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica css site 404 right please fix site unusable
# neg 0.0 , neu 0.777 , pos 0.223 , normalized_sum 0.3182
# Predicted: non-negative , Actual: negative
#
# virginamerica flight 910 vega boston today check online bag count register fix somehow
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica classiq love virgin america greetingz
# neg 0.0 , neu 0.543 , pos 0.457 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica hi try checkin website work try 3 different browser problem continue
# neg 0.213 , neu 0.787 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: negative
#
# virginamerica thanks great customer service today help get travel sort
# neg 0.0 , neu 0.419 , pos 0.581 , normalized_sum 0.8658
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thanks guy sweet route rockies airplanemodewason
# neg 0.0 , neu 0.459 , pos 0.541 , normalized_sum 0.7096
# Predicted: non-negative , Actual: non-negative
#
# virginamerica love 90 music blast gate boston wait flight sanfrancisco could get iced coffee
# neg 0.0 , neu 0.756 , pos 0.244 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# virginamerica passenger 7d flt 338 assault flown trust ban crew file report faanews
# neg 0.357 , neu 0.483 , pos 0.159 , normalized_sum -0.6249
# Predicted: negative , Actual: negative
#
# virginamerica current bug website show select departure city select destination city
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica luggage severely dentedmissing wheel come baggage claim san luggage agent miranda think help
# neg 0.169 , neu 0.678 , pos 0.153 , normalized_sum -0.0772
# Predicted: negative , Actual: negative
#
# virginamerica thank easy itinerary shift impend weather quick painless free
# neg 0.0 , neu 0.355 , pos 0.645 , normalized_sum 0.872
# Predicted: non-negative , Actual: non-negative
#
# virginamerica would love see girl inspire become pilot rt free woaw event march 28 abq
# neg 0.0 , neu 0.517 , pos 0.483 , normalized_sum 0.9042
# Predicted: non-negative , Actual: non-negative
#
# virginamerica thanks good time back vodkatonics entire flightsfo
# neg 0.0 , neu 0.508 , pos 0.492 , normalized_sum 0.7003
# Predicted: non-negative , Actual: non-negative
#
# virginamerica beat expectation share take santa cruz sentinel
# neg 0.0 , neu 0.761 , pos 0.239 , normalized_sum 0.296
# Predicted: non-negative , Actual: non-negative
#
# virginamerica plan start fly direct dal la
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica big lovegratitudempower w werin oscars2105 vipswagbags avalonhollywood
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica great job add little luxuriesaesthetics improve air travel experience thank keep
# neg 0.0 , neu 0.494 , pos 0.506 , normalized_sum 0.849
# Predicted: non-negative , Actual: non-negative
#
# virginamerica request window seat confirm window get stuck middle seat good way treat silver member
# neg 0.102 , neu 0.612 , pos 0.286 , normalized_sum 0.5574
# Predicted: non-negative , Actual: negative
# virginamerica grand budapest hotel oscarscountdown
# neg 0.0 , neu 0.571 , pos 0.429 , normalized_sum 0.4588
# Predicted: non-negative , Actual: non-negative
#
# virginamerica miss newsvp next trip 407
# neg 0.242 , neu 0.758 , pos 0.0 , normalized_sum -0.1531
# Predicted: negative , Actual: non-negative
#
# virginamerica wtf pay direct flight purpose stop fuel exhaust frequent flier nothing inconvenience
# neg 0.487 , neu 0.406 , pos 0.107 , normalized_sum -0.7572
# Predicted: negative , Actual: negative
#
# virginamerica something wrong website safari iphone
# neg 0.383 , neu 0.617 , pos 0.0 , normalized_sum -0.4767
# Predicted: negative , Actual: negative
#
# virginamerica thanks gate check baggage full flight dfwlax 883 give early boarding sweet
# neg 0.0 , neu 0.651 , pos 0.349 , normalized_sum 0.7096
# Predicted: non-negative , Actual: non-negative
#
# virginamerica already check page expire x
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica boo refund seat upgrade fee want buy first place
# neg 0.0 , neu 0.874 , pos 0.126 , normalized_sum 0.0772
# Predicted: non-negative , Actual: negative
#
# virginamerica share rise q4 financial result usa today
# neg 0.0 , neu 0.761 , pos 0.239 , normalized_sum 0.296
# Predicted: non-negative , Actual: non-negative
#
# virginamerica add pillow instead lieflat seat first class arm race
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica see
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica way take advantage mayweatherpacquiao
# neg 0.0 , neu 0.667 , pos 0.333 , normalized_sum 0.25
# Predicted: non-negative , Actual: non-negative
#
# virginamerica know fly virgin fight mayweatherpacquiao
# neg 0.342 , neu 0.658 , pos 0.0 , normalized_sum -0.3818
# Predicted: negative , Actual: non-negative
#
# virginamerica inflight team make experience amaze
# neg 0.0 , neu 0.588 , pos 0.412 , normalized_sum 0.5423
# Predicted: non-negative , Actual: non-negative
#
# virginamerica cut salt pepper shaker ever think guy get good
# neg 0.162 , neu 0.615 , pos 0.223 , normalized_sum 0.2023
# Predicted: non-negative , Actual: non-negative
#
# virginamerica move seat notice well seat cabin select behind row select disappointed
# neg 0.204 , neu 0.658 , pos 0.138 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# virginamerica share 4q result iol
# neg 0.441 , neu 0.323 , pos 0.237 , normalized_sum -0.4404
# Predicted: negative , Actual: non-negative
#
# virginamerica fav airline
# neg 0.0 , neu 0.4 , pos 0.6 , normalized_sum 0.4588
# Predicted: non-negative , Actual: non-negative
#
# virginamerica hot female pilot sweet dca sfo
# neg 0.0 , neu 0.667 , pos 0.333 , normalized_sum 0.4588
# Predicted: non-negative , Actual: non-negative
#
# guy go start fly paris virginamerica lizautter welcome
# neg 0.0 , neu 0.7 , pos 0.3 , normalized_sum 0.4588
# Predicted: non-negative , Actual: non-negative
#
# virginamerica policy fly surgery still wait answer tell doctor
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica already contacted central baggage send dm renttherunway charge dress lose suitcase help
# neg 0.165 , neu 0.671 , pos 0.165 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# virginamerica thank
# neg 0.0 , neu 0.286 , pos 0.714 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# virginamerica anything go website get lot error past 30 minute
# neg 0.231 , neu 0.769 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: negative
#
# virginamerica think leave something plane yesterday callah
# neg 0.167 , neu 0.833 , pos 0.0 , normalized_sum -0.0516
# Predicted: negative , Actual: non-negative
#
# virginamerica need follow back order dm
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica need start fly kciairport
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica tell check airline regulation first contact
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# virginamerica virginatlantic check flight sfo lax tell atlantic fly club gold get benefit
# neg 0.0 , neu 0.8 , pos 0.2 , normalized_sum 0.4588
# ...
# Predicted: negative , Actual: non-negative
#
# eliza cheat americanair airtahitinui lovely flight back lot
# neg 0.234 , neu 0.469 , pos 0.297 , normalized_sum 0.2023
# Predicted: non-negative , Actual: non-negative
#
# americanair hope like photo
# neg 0.0 , neu 0.27 , pos 0.73 , normalized_sum 0.6597
# Predicted: non-negative , Actual: non-negative
#
# americanair sweetmel weather bad would folks try extra hard communicateor load bag onto flight 1320oranything
# neg 0.274 , neu 0.726 , pos 0.0 , normalized_sum -0.5994
# Predicted: negative , Actual: negative
#
# americanair mechanical issue evidence point idea il cll fault weather
# neg 0.231 , neu 0.769 , pos 0.0 , normalized_sum -0.4019
# Predicted: negative , Actual: negative
#
# americanair caexhibitions sorry like general way sorry incompetenceunderstaffing compound weather issue
# neg 0.198 , neu 0.611 , pos 0.191 , normalized_sum 0.2263
# Predicted: non-negative , Actual: negative
#
# americanair please help u get home tomorrow
# neg 0.0 , neu 0.444 , pos 0.556 , normalized_sum 0.6124
# Predicted: non-negative , Actual: non-negative
#
# americanair tennetexan bad like 3 people team next level unreal
# neg 0.269 , neu 0.538 , pos 0.192 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# americanair marxsterbcow real life response customer service issue seriously keep try call u eh might work
# neg 0.108 , neu 0.892 , pos 0.0 , normalized_sum -0.1779
# Predicted: negative , Actual: negative
#
# americanair fix engine flight aa3031so spend night airport fly home tomorrow
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair actingoutmgmnt make sure remember load bag onto plane cancel flight flight forget
# neg 0.241 , neu 0.617 , pos 0.142 , normalized_sum -0.1531
# Predicted: negative , Actual: negative
#
# americanair brewcrewfan8 real life aa like 2015 real life emailingcallingdming people inconvenience
# neg 0.167 , neu 0.667 , pos 0.167 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair hey yesterday still hold
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair weather unavoidable understaffing controllable
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair 5418 late flight board wait 30min wtf
# neg 0.352 , neu 0.648 , pos 0.0 , normalized_sum -0.5859
# Predicted: negative , Actual: negative
#
# americanair yvonneokaka get personal response apology crew forget load baggage onto flight
# neg 0.145 , neu 0.763 , pos 0.092 , normalized_sum -0.1779
# Predicted: negative , Actual: negative
#
# americanair flts jfk cancel flightled thx ur agent sfo rebooked ua get name awesome twitterhug shesaidrun
# neg 0.093 , neu 0.602 , pos 0.306 , normalized_sum 0.6808
# Predicted: non-negative , Actual: negative
#
# americanair know hour get live person mess arrival car plan two airport cost u
# neg 0.172 , neu 0.828 , pos 0.0 , normalized_sum -0.3612
# Predicted: negative , Actual: negative
#
# americanair get ahold aadvantage reservation need ticket reservation cancel flight soon help
# neg 0.136 , neu 0.68 , pos 0.184 , normalized_sum 0.1779
# Predicted: non-negative , Actual: non-negative
#
# americanair also tell agent issue prob k fine get compassion 4 others deal wthis
# neg 0.0 , neu 0.676 , pos 0.324 , normalized_sum 0.5859
# Predicted: non-negative , Actual: negative
#
# americanair status dfw ticket agent gate a9 rude unhelpful
# neg 0.273 , neu 0.727 , pos 0.0 , normalized_sum -0.4588
# Predicted: negative , Actual: negative
#
# americanair speak 2 like idiot ok need deal w esp travel experience
# neg 0.22 , neu 0.467 , pos 0.313 , normalized_sum 0.1027
# Predicted: non-negative , Actual: negative
#
# americanair try switch flight aa 1359 currently aa 2401 650am monday morn aa 2586 help
# neg 0.0 , neu 0.838 , pos 0.162 , normalized_sum 0.4019
# Predicted: non-negative , Actual: non-negative
#
# americanair really hope departs say cater service available see next plane nthin
# neg 0.0 , neu 0.775 , pos 0.225 , normalized_sum 0.4927
# Predicted: non-negative , Actual: negative
#
# americanair understand weather fault ur c rep atrocious happy evr fly w
# neg 0.188 , neu 0.556 , pos 0.257 , normalized_sum 0.25
# Predicted: non-negative , Actual: negative
#
# americanair leave orlando 2nd line standby land 4th priority member get first available seat awesome
# neg 0.066 , neu 0.71 , pos 0.224 , normalized_sum 0.5994
# Predicted: non-negative , Actual: negative
#
# americanair respond dm tweet canned tweet tell everyone else
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair dmed aa phone someone call point response resolve anything
# neg 0.0 , neu 0.776 , pos 0.224 , normalized_sum 0.3818
# Predicted: non-negative , Actual: negative
#
# americanair guy email address put next available flight ohare
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair eagle always late flight
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair never trip airline ever natl intl ever experience anything like
# neg 0.0 , neu 0.8 , pos 0.2 , normalized_sum 0.3612
# Predicted: non-negative , Actual: negative
#
# americanair call center let wait hold would happily seriously suppose keep call great
# neg 0.088 , neu 0.515 , pos 0.397 , normalized_sum 0.7906
# Predicted: non-negative , Actual: negative
#
# americanair half hour late flight leave dfwno attempt explanation
# neg 0.13 , neu 0.87 , pos 0.0 , normalized_sum -0.0516
# Predicted: negative , Actual: negative
#
# americanair flight 1027 tomorrow get cancel flightled need find alternative get dallas please help
# neg 0.111 , neu 0.611 , pos 0.278 , normalized_sum 0.4588
# Predicted: non-negative , Actual: negative
#
# americanair 30 minute flight okc make u wait 30 minute gate empty epicfail poorplanning
# neg 0.13 , neu 0.87 , pos 0.0 , normalized_sum -0.2023
# Predicted: negative , Actual: negative
#
# americanair seem like queue time high q wait agent 4 almost hourflight get cancel flightled
# neg 0.114 , neu 0.722 , pos 0.164 , normalized_sum 0.1935
# Predicted: non-negative , Actual: negative
#
# americanair nah horrible dining option outside club luckily manuel admiral make bloody mary
# neg 0.364 , neu 0.374 , pos 0.262 , normalized_sum -0.296
# Predicted: negative , Actual: negative
#
# americanair earlier flight sapmia mia new york lga 0303 currently book flight 1504 1102
# neg 0.145 , neu 0.855 , pos 0.0 , normalized_sum -0.296
# Predicted: negative , Actual: non-negative
#
# americanair hold time disconnection excuse
# neg 0.0 , neu 0.755 , pos 0.245 , normalized_sum 0.0772
# Predicted: non-negative , Actual: negative
#
# americanair nice 2 know pay 4 seat sell seat buy 3rd seat good scam scam
# neg 0.391 , neu 0.356 , pos 0.253 , normalized_sum -0.4767
# Predicted: negative , Actual: negative
#
# americanair play ear know best buy chewey oatmeal cooky customer care folk
# neg 0.0 , neu 0.479 , pos 0.521 , normalized_sum 0.8689
# Predicted: non-negative , Actual: negative
#
# americanair business class full 1st class empty guy upgrade exp member 1st
# neg 0.141 , neu 0.859 , pos 0.0 , normalized_sum -0.2023
# Predicted: negative , Actual: non-negative
#
# americanair try 4 hour get hold someone
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair thank quick response aa usually fantastic customer service shock
# neg 0.166 , neu 0.446 , pos 0.389 , normalized_sum 0.5423
# Predicted: non-negative , Actual: non-negative
#
# americanair chance make connection el paso aa504 dfw sit aa200 delay 30 minute
# neg 0.15 , neu 0.719 , pos 0.131 , normalized_sum -0.0772
# Predicted: negative , Actual: negative
#
# americanair beyond frustrate call back auto hold whatever call enter number 1130 cst still call 226
# neg 0.164 , neu 0.765 , pos 0.071 , normalized_sum -0.4019
# Predicted: negative , Actual: negative
#
# americanair ahhhh silence golden top anyone get fire
# neg 0.235 , neu 0.588 , pos 0.176 , normalized_sum -0.1531
# Predicted: negative , Actual: negative
#
# americanair hey aa help itinerary plat custy stick pvr phone work
# neg 0.0 , neu 0.787 , pos 0.213 , normalized_sum 0.4019
# Predicted: non-negative , Actual: negative
#
# americanair shannonbloom dm voucher pay 70 cab 50 car back jfk tomorrow
# neg 0.113 , neu 0.887 , pos 0.0 , normalized_sum -0.1027
# Predicted: negative , Actual: negative
#
# americanair hold hour
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair stone9956 dislike delay cause crew forget load bag lazy pilot want duty day end
# neg 0.451 , neu 0.485 , pos 0.063 , normalized_sum -0.7906
# Predicted: negative , Actual: negative
#
# americanair guy help please
# neg 0.0 , neu 0.286 , pos 0.714 , normalized_sum 0.6124
# Predicted: non-negative , Actual: non-negative
#
# americanair travisamex weather also gross incompetence understaffing crew forget load bag duck truth
# neg 0.423 , neu 0.459 , pos 0.117 , normalized_sum -0.7184
# Predicted: negative , Actual: negative
#
# robertss1 americanair
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# americanair wait 5 hour stuffy plane could get 7 hr get luggage americanairlines
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair guy another flight today book laguardia louisville ky
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: non-negative
#
# americanair flight tyr tomorrow cancel flight due weather long rebook
# neg 0.182 , neu 0.818 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# americanair aa flight 296 san antonio dallas cancel flighted
# neg 0.2 , neu 0.8 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# americanair try book flight hold get representative phone advice
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair cancel flight flight arbitrarily itinerary weekend ruin good reason crew miss monday mtg
# neg 0.365 , neu 0.493 , pos 0.143 , normalized_sum -0.5423
# Predicted: negative , Actual: negative
#
# americanair need someone help
# neg 0.0 , neu 0.526 , pos 0.474 , normalized_sum 0.4019
# Predicted: non-negative , Actual: non-negative
#
# americanair flight cancel flightled laguardia louisville ky stuck airport guy compensate
# neg 0.308 , neu 0.692 , pos 0.0 , normalized_sum -0.4588
# Predicted: negative , Actual: negative
#
# americanair enough staff rude ignore passengersdo think accept whatever reason
# neg 0.364 , neu 0.464 , pos 0.172 , normalized_sum -0.4404
# Predicted: negative , Actual: negative
#
# americanair understand weather issue expect passenger wait 24 hour inside airport whatever reason outrageous
# neg 0.188 , neu 0.812 , pos 0.0 , normalized_sum -0.4588
# Predicted: negative , Actual: negative
#
# americanair guarantee retribution would glad share
# neg 0.0 , neu 0.294 , pos 0.706 , normalized_sum 0.7351
# Predicted: non-negative , Actual: non-negative
#
# americanair friend flight cancel flightlations lax cmh feb 23 anyway help 800 number help
# neg 0.096 , neu 0.431 , pos 0.474 , normalized_sum 0.7845
# Predicted: non-negative , Actual: negative
#
# americanair use call back feature operator regard flight get call 2 hour late flightr get hung pleasehelp
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair need work tomorrow 8am therefore help direct message faster call 800 number backwards
# neg 0.0 , neu 0.75 , pos 0.25 , normalized_sum 0.4588
# Predicted: non-negative , Actual: negative
#
# americanair ugh dump u dfw wno luggage cancel flight flight 3 time sat arrival tue
# neg 0.425 , neu 0.575 , pos 0.0 , normalized_sum -0.7506
# Predicted: negative , Actual: negative
#
# americanair cancel flight flight send email text call put way earlier flight might miss thanks aa
# neg 0.185 , neu 0.667 , pos 0.149 , normalized_sum 0.0772
# Predicted: non-negative , Actual: negative
#
# americanair dming big thanks
# neg 0.0 , neu 0.508 , pos 0.492 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# americanair 3078 overweight pull 2 dozen passenger luggage seriously
# neg 0.412 , neu 0.588 , pos 0.0 , normalized_sum -0.4939
# Predicted: negative , Actual: negative
#
# americanair love company staff amaze make uncomfortable situation comfortable
# neg 0.14 , neu 0.269 , pos 0.591 , normalized_sum 0.8555
# Predicted: non-negative , Actual: non-negative
#
# americanair wait 2 hr c call back flt cxldprotection hang minute answer 1st ring
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair hold 55 min cancel flighted international flight country leave call back help
# neg 0.201 , neu 0.629 , pos 0.17 , normalized_sum 0.128
# Predicted: non-negative , Actual: negative
#
# need place sleep land without accommodation pls americanair
# neg 0.149 , neu 0.851 , pos 0.0 , normalized_sum -0.0572
# Predicted: negative , Actual: negative
#
# americanair love new plane jfklax run maybe one day one amenities function nocharge ever
# neg 0.0 , neu 0.756 , pos 0.244 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# americanair call chairman call emerald today call former customer
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair flight 236 great fantastic cabin crew land thankyou jfk
# neg 0.0 , neu 0.51 , pos 0.49 , normalized_sum 0.8271
# Predicted: non-negative , Actual: non-negative
#
# americanair flight 953 nycbuenos aire delay since yesterday 10pm go take 330pm give u answer
# neg 0.15 , neu 0.85 , pos 0.0 , normalized_sum -0.3182
# Predicted: negative , Actual: negative
#
# americanair flight cancel flightled go home tomorrow could use dinner play americanair first time nyc
# neg 0.115 , neu 0.747 , pos 0.138 , normalized_sum 0.1027
# Predicted: non-negative , Actual: negative
#
# thank americanair jlhalldc customer relation review concern contact back directly john
# neg 0.0 , neu 0.8 , pos 0.2 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# americanair change flight phone system keep tell representative busy
# neg 0.0 , neu 1.0 , pos 0.0 , normalized_sum 0.0
# Predicted: negative , Actual: negative
#
# americanair thanks
# neg 0.0 , neu 0.256 , pos 0.744 , normalized_sum 0.4404
# Predicted: non-negative , Actual: non-negative
#
# americanair thx nothing get u country back u broken plane come get another one
# neg 0.199 , neu 0.641 , pos 0.16 , normalized_sum -0.1531
# Predicted: negative , Actual: negative
#
# americanair tilleymonsta george look good please follow link start refund process
# neg 0.0 , neu 0.634 , pos 0.366 , normalized_sum 0.6369
# Predicted: non-negative , Actual: non-negative
#
# americanair flight cancel flightled leaving tomorrow morning auto rebooked tuesday night flight need arrive monday
# neg 0.125 , neu 0.875 , pos 0.0 , normalized_sum -0.25
# Predicted: negative , Actual: negative
#
# americanair right cue delay
# neg 0.434 , neu 0.566 , pos 0.0 , normalized_sum -0.3182
# Predicted: negative , Actual: negative
#
# americanair thank get different flight chicago
# neg 0.0 , neu 0.667 , pos 0.333 , normalized_sum 0.3612
# Predicted: non-negative , Actual: non-negative
#
# americanair leave 20 minute late flight warning communication 15 minute late flight call shitty customer svc
# neg 0.356 , neu 0.644 , pos 0.0 , normalized_sum -0.7351
# Predicted: negative , Actual: negative
#
# americanair please bring american airline blackberry10
# neg 0.0 , neu 0.685 , pos 0.315 , normalized_sum 0.3182
# Predicted: non-negative , Actual: non-negative
#
# americanair money change flight answer phone suggestion make commitment
# neg 0.0 , neu 0.755 , pos 0.245 , normalized_sum 0.3818
# Predicted: non-negative , Actual: negative
#
# americanair 8 ppl need 2 know many seat next flight plz put u standby 4 people next flight
# neg 0.0 , neu 0.909 , pos 0.091 , normalized_sum 0.0772
# Predicted: non-negative , Actual: non-negative

# %%
# Evaluation of VADER results
text_all = textdf.lemmatized_text_str
y = textdf.airline_sentiment
pred_list = [predict_sentiment(review, printout=False, sentiment=y[0]) for review in text_all]
predicted = pd.DataFrame(pred_list, columns=['pred'])

from sklearn import metrics
from sklearn.metrics import confusion_matrix
print('Evaluation results:\n' + 'Accuracy:', metrics.accuracy_score(y, predicted))
cm = pd.DataFrame(confusion_matrix(y, predicted, labels=['non-negative', 'negative']),
                  index=['actual non-negative', 'actual negative'],
                  columns=['predicted non-negative', 'predicted negative'])
print('Confusion matrix:\n', cm)
TP = cm.at['actual non-negative', 'predicted non-negative']
FP = cm.at['actual negative', 'predicted non-negative']
FN = cm.at['actual non-negative', 'predicted negative']
TN = cm.at['actual negative', 'predicted negative']
print('precision =', TP/(TP+FP), ', recall =', TP/(TP+FN), ', F1-score =', 2*TP/(2*TP+FP+FN), ', Specificity =', TN/(TN+FP))
# Out:
# Evaluation results:
# Accuracy: 0.5995150675441635
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                    3777                1571
# actual negative                        4210                4877
# precision = 0.47289345185927134 , recall = 0.706245325355273 , F1-score = 0.5664791901012374 , Specificity = 0.5367007813359744

# %% [markdown]
# # TFIDF matric with Lemmatization

# %%
# Compute term-document (tf) matrix and TFIDF matrix with lemmatization
import nltk
import string
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

def lemma_tokenizer(corpus):   # a method to lemmatize corpus
    corpus = ''.join([ch for ch in corpus if ch not in string.punctuation])  # remove punctuation
    tokens = nltk.word_tokenize(corpus)
    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(token) for token in tokens]

# use nltk stopwords list
nltk_stopwords = nltk.corpus.stopwords.words('english')
print(nltk_stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# # Split data for holdout test

# %%
# Split data for holdout test
from sklearn.model_selection import train_test_split
text_train, text_test, y_train, y_test = train_test_split(text_all, y, test_size=0.2, random_state=12)

# Compute term-document (tf) matrix with lemmatization
tf = CountVectorizer(tokenizer=lemma_tokenizer,  # use lemma_tokenizer
                     stop_words=nltk_stopwords,  # use customized stopwords list
                     ngram_range=(1,2))          # use unigrams and bigrams
tf_train = tf.fit_transform(text_train)
tf_train
# Out:
# C:\DoPython\venv39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['arent', 'couldnt', 'didnt', 'doe', 'doesnt', 'dont', 'ha', 'hadnt', 'hasnt', 'havent', 'isnt', 'mightnt', 'mustnt', 'neednt', 'shant', 'shes', 'shouldnt', 'shouldve', 'thatll', 'wa', 'wasnt', 'werent', 'wont', 'wouldnt', 'youd', 'youll', 'youre', 'youve'] not in stop_words.
#   warnings.warn(
# <11548x80867 sparse matrix of type '<class 'numpy.int64'>'
# 	with 215965 stored elements in Compressed Sparse Row format>

# %%
print(text_test, '\n', y_test)
tf_test = tf.transform(text_test)
tf_test
# Out:
# 3722     united fantastic job people today ua22 dublin ...
# 14175    americanair kid one answer call reserv line du...
# 5619     southwestairs ceo kelly draws record crowd bwi...
# 7011                cmon bad jetbae rt jetblue fleet fleek
# 1224     united thanks link finally arrive brussels 9 h...
#                                ...
# 12343    americanair 6am flight get rest wait another 2...
# 12462    americanair add insult injury go pick real cla...
# 11755        usairways miss funeral take train back newark
# 7389     jetblue tell guy help u sit next 5 8 year old ...
# 5875     southwestair ifthe80sneverstopped would still ...
# Name: lemmatized_text_str, Length: 2887, dtype: object
#  3722     non-negative
# 14175        negative
# 5619     non-negative
# 7011         negative
# 1224         negative
#              ...
# 12343        negative
# 12462        negative
# 11755        negative
# 7389         negative
# 5875     non-negative
# Name: airline_sentiment, Length: 2887, dtype: object
# <2887x80867 sparse matrix of type '<class 'numpy.int64'>'
# 	with 37950 stored elements in Compressed Sparse Row format>

# %%
# term-document (tf) matrix for the entire corpus - for cv test
tf_all = tf.fit_transform(text_all)
tf_all
# Out:
# <14435x97096 sparse matrix of type '<class 'numpy.int64'>'
# 	with 270543 stored elements in Compressed Sparse Row format>

# %%
# Compute tfidf matrix with lemmatization
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(tokenizer=lemma_tokenizer,  # use lemma_tokenizer
                        stop_words=nltk_stopwords,  # use customized stopwords list
                        ngram_range=(1,2))          # use unigrams and bigrams
tfidf_train = tfidf.fit_transform(text_train)
tfidf_train
# Out:
# C:\DoPython\venv39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['arent', 'couldnt', 'didnt', 'doe', 'doesnt', 'dont', 'ha', 'hadnt', 'hasnt', 'havent', 'isnt', 'mightnt', 'mustnt', 'neednt', 'shant', 'shes', 'shouldnt', 'shouldve', 'thatll', 'wa', 'wasnt', 'werent', 'wont', 'wouldnt', 'youd', 'youll', 'youre', 'youve'] not in stop_words.
#   warnings.warn(
# <11548x80867 sparse matrix of type '<class 'numpy.float64'>'
# 	with 215965 stored elements in Compressed Sparse Row format>

# %%
tfidf_test = tfidf.transform(text_test)
tfidf_test
# Out:
# <2887x80867 sparse matrix of type '<class 'numpy.float64'>'
# 	with 37950 stored elements in Compressed Sparse Row format>

# %%
# tfidf matrix for the entire corpus - for cv test
tfidf_all = tfidf.fit_transform(text_all)
tfidf_all
# Out:
# <14435x97096 sparse matrix of type '<class 'numpy.float64'>'
# 	with 270543 stored elements in Compressed Sparse Row format>

# %%
# Method to perform holdout test
def holdout_test(model, X_train, y_train, X_test, y_test, title):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(title, '\nAccuracy:', metrics.accuracy_score(y_test, y_pred))
    cm = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=['non-negative', 'negative']),
                      index=['actual non-negative', 'actual negative'],
                      columns=['predicted non-negative', 'predicted negative'])
    print('Confusion matrix:\n', cm)
    TP = cm.at['actual non-negative', 'predicted non-negative']
    FP = cm.at['actual negative', 'predicted non-negative']
    FN = cm.at['actual non-negative', 'predicted negative']
    TN = cm.at['actual negative', 'predicted negative']
    print('precision =', TP/(TP+FP), ', recall =', TP/(TP+FN), ', F1-score =', 2*TP/(2*TP+FP+FN), ', specificity =', TN/(TN+FP))

# Method to perform cross-validation test using for loop
from sklearn.model_selection import StratifiedKFold
kf = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)

def cv_test(model, X_sparse, y, title):  # X_sparse is a scipy.sparse.csr_matrix (tf or tfidf matrix)
    num_total_tested = 0
    num_correctly_classified = 0   # to calculate average accuracy over k test sets
    cm_sum = np.zeros((2,2)) # initialize a 2x2 confusion matrix (cm) for summing up the cm's from all folds
    for train_index, test_index in kf.split(X_sparse, y):
        X_train, X_test = tf_all[train_index], tf_all[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        # print('X_train.shape:', X_train.shape, '\ny_train.index:', y_train.index)
        # print('X_test.shape:', X_test.shape, '\ny_test.index:', y_test.index)
        # print('X_train:\n', X_train, '\ny_train\n', y_train)
        # print('X_test:\n', X_test, '\ny_test\n', y_test)
        model.fit(X_train, y_train)
        num_total_tested += len(y_test)   # num_total_tested = num_total_tested + len(y_test)
        num_correctly_classified += metrics.accuracy_score(y_test, model.predict(X_test), normalize=False)
        # print(num_total_tested, num_correctly_classified)
        cm = pd.DataFrame(confusion_matrix(y_test, model.predict(X_test), labels=['non-negative', 'negative']), 
                          index=['actual non-negative', 'actual negative'], 
                          columns=['predicted non-negative', 'predicted negative'])
        # print(cm)
        cm_sum += cm

    print(title, '\nAverage accuracy:', num_correctly_classified/num_total_tested)
    print('Confusion matrix:\n', cm_sum)
    print("'Negative' is the Target Class")
    TP = cm.at['actual non-negative', 'predicted non-negative']
    FP = cm.at['actual negative', 'predicted non-negative']
    FN = cm.at['actual non-negative', 'predicted negative']
    TN = cm.at['actual negative', 'predicted negative']
    print('precision =', TP/(TP+FP), ', recall =', TP/(TP+FN), ', F1-score =', 2*TP/(2*TP+FP+FN), ', specificity =', TN/(TN+FP))


# Method to perform cross-validation test using cross_val_score - results are inaccurate

# To get precision, recall and F1 scores from cross_val_score(), y values must be labeled {0,1}
# when cross_val_score() computes these scores, it always considers 1 as 'positive' (and 0 as 'negative')
y01 = y.apply(lambda x: 1 if x=='non-negative' else 0) # the scores are calculated by considering '+' as 'Non-Negative'
# y01 = y.apply(lambda x: 1 if x=='negative' else 0) # the scores are calculated by considering '-' as 'Negative'

from sklearn.model_selection import cross_val_score
n_folds = 5
def cv_test_inaccurate(model, X_sparse, y01, title):
    print(title)
    accuracy = cross_val_score(model, X_sparse, y01, cv=n_folds, scoring='accuracy')
    # print('Accuracy for each fold:', accuracy)
    print('Average accuracy:', accuracy.mean())
    precision = cross_val_score(model, X_sparse, y01, cv=n_folds, scoring='precision')
    # print('Precision:', precision)
    print('Average precision:', precision.mean())
    recall = cross_val_score(model, X_sparse, y01, cv=n_folds, scoring='recall')
    # print('Recall:', recall)
    print('Average recall:', precision.mean())
    f1 = cross_val_score(model, X_sparse, y01, cv=n_folds, scoring='f1')
    # print('F-1 score:',f1)
    print('Average F-1 score:', f1.mean())

# %% [markdown]
# # Naive Bayes

# %%
# Sentiment analysis using Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
holdout_test(mnb, tf_train, y_train, tf_test, y_test, 'Naive Bayes holdout test with tf matrix:')
holdout_test(mnb, tfidf_train, y_train, tfidf_test, y_test, '\nNaive Bayes holdout test with tfidf matrix:')
# Out:
# Naive Bayes holdout test with tf matrix:
# Accuracy: 0.8112227225493592
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     589                 452
# actual negative                          93                1753
# precision = 0.8636363636363636 , recall = 0.5658021133525456 , F1-score = 0.6836912362159024 , specificity = 0.9496208017334777
#
# Naive Bayes holdout test with tfidf matrix:
# Accuracy: 0.7620367163145133
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     377                 664
# actual negative                          23                1823
# precision = 0.9425 , recall = 0.3621517771373679 , F1-score = 0.5232477446217905 , specificity = 0.9875406283856988

# %% [markdown]
# # Logistic Regression

# %%
# Sentiment analysis using logistic regression
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression(random_state=1)
holdout_test(logit, tf_train, y_train, tf_test, y_test, 'Logistic regression holdout test with tf matrix:')
holdout_test(logit, tfidf_train, y_train, tfidf_test, y_test, '\nLogistic reg holdout test with tfidf matrix:')
# Out:
# Logistic regression holdout test with tf matrix:
# Accuracy: 0.828195358503637
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     785                 256
# actual negative                         240                1606
# precision = 0.7658536585365854 , recall = 0.7540826128722382 , F1-score = 0.7599225556631172 , specificity = 0.8699891657638137
#
# Logistic reg holdout test with tfidf matrix:
# Accuracy: 0.8146865258053343
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     675                 366
# actual negative                         169                1677
# precision = 0.7997630331753555 , recall = 0.6484149855907781 , F1-score = 0.7161803713527851 , specificity = 0.9084507042253521

# %% [markdown]
# # Support Vector Classifier SVC

# %%
# Sentiment analysis using support vector classifier (SVC)
from sklearn.svm import SVC
svc = SVC(kernel='linear')
holdout_test(svc, tf_train, y_train, tf_test, y_test, 'SVC holdout test with tf matrix:')
holdout_test(svc, tfidf_train, y_train, tfidf_test, y_test, '\nSVC holdout test with tfidf matrix:')
# Out:
# SVC holdout test with tf matrix:
# Accuracy: 0.8112227225493592
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     802                 239
# actual negative                         306                1540
# precision = 0.723826714801444 , recall = 0.7704130643611912 , F1-score = 0.7463936714751047 , specificity = 0.8342361863488624
#
# SVC holdout test with tfidf matrix:
# Accuracy: 0.828195358503637
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     754                 287
# actual negative                         209                1637
# precision = 0.7829698857736241 , recall = 0.7243035542747358 , F1-score = 0.7524950099800399 , specificity = 0.8867822318526544

# %% [markdown]
# # Decision Tree

# %%
# Sentiment analysis using decision trees
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(random_state=1)
holdout_test(tree, tf_train, y_train, tf_test, y_test, 'Decision tree holdout test with tf matrix:')
holdout_test(tree, tfidf_train, y_train, tfidf_test, y_test, '\nDecision tree holdout test with tfidf matrix:')
# Out:
# Decision tree holdout test with tf matrix:
# Accuracy: 0.7519916868721856
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     678                 363
# actual negative                         353                1493
# precision = 0.6576139670223085 , recall = 0.6512968299711815 , F1-score = 0.6544401544401545 , specificity = 0.8087757313109426
#
# Decision tree holdout test with tfidf matrix:
# Accuracy: 0.7028056806373398
# Confusion matrix:
#                       predicted non-negative  predicted negative
# actual non-negative                     730                 311
# actual negative                         547                1299
# precision = 0.5716523101018011 , recall = 0.7012487992315082 , F1-score = 0.6298533218291631 , specificity = 0.7036836403033586
